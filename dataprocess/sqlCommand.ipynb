# %%
import MySQLdb

# %%
ingre_dish = {'egg': ['https://www.myrecipes.com/recipe/our-homemade-quick-black-bean-burger',
  'http://www.myrecipes.com/recipe/red-snapper-with-lemon-sauce',
  'https://www.myrecipes.com/recipe/asian-style-meat-loaves',
  'https://www.myrecipes.com/recipe/crispy-tofu-pad-thai-0',
  'https://www.myrecipes.com/recipe/red-lentil-burgers-with-aioli',
  'http://www.myrecipes.com/recipe/tofu-cheese-stuffed-manicotti',
  'https://www.myrecipes.com/recipe/swanson-sensational-chicken-noodle-soup',
  'http://www.myrecipes.com/recipe/swanson-chicken-broccoli-dijon'],
 'milk': ['https://www.myrecipes.com/recipe/fried-chicken-wings',
  'http://www.myrecipes.com/recipe/broccoli-cheese-rice-casserole',
  'http://www.myrecipes.com/recipe/cheddar-cheese-soup',
  'https://www.myrecipes.com/recipe/fish-stew',
  'https://www.myrecipes.com/recipe/fish-sticks',
  'https://www.myrecipes.com/recipe/curried-chicken-saute',
  'https://www.myrecipes.com/recipe/broccoli-rice-casseroles',
  'http://www.myrecipes.com/recipe/cauliflower-soup-with-shiitake',
  'https://www.myrecipes.com/recipe/spicy-beans-with-coconut-milk',
  'http://www.myrecipes.com/recipe/strawberries-with-crme-anglaise',
  'http://www.myrecipes.com/recipe/tomato-basil-soup',
  'https://www.myrecipes.com/recipe/broccoli-cheese-rice-casserole-0',
  'http://www.myrecipes.com/recipe/beef-cheese-noodle-bake',
  'https://www.myrecipes.com/recipe/cauliflower-coconut-curry-sauce',
  'http://www.myrecipes.com/recipe/cheese-broccoli-rice-bake',
  'http://www.myrecipes.com/recipe/swanson-chicken-broccoli-dijon',
  'https://www.myrecipes.com/recipe/roasted-cauliflower-mashed-potatoes',
  'http://www.myrecipes.com/recipe/fish-pie',
  'https://www.myrecipes.com/recipe/chilled-avocado-soup',
  'http://www.myrecipes.com/recipe/broccoli-rice-cheese-bake',
  'https://www.myrecipes.com/recipe/cauliflower-green-onion-mash',
  'https://www.myrecipes.com/recipe/fish-chowder-1',
  'https://www.myrecipes.com/recipe/cheesy-broccoli-rice-casserole',
  'https://www.myrecipes.com/recipe/fish-chips-0',
  'http://www.myrecipes.com/recipe/red-snapper-with-lemon-sauce',
  'https://www.myrecipes.com/recipe/roasted-carrot-and-coconut-soup'],
 'avocado': ['https://www.myrecipes.com/recipe/rice-beans-with-avocado',
  'https://www.myrecipes.com/recipe/fish-tacos-2',
  'https://www.myrecipes.com/recipe/tex-mex-rice-salad',
  'https://www.myrecipes.com/recipe/blast-sandwich',
  'http://www.myrecipes.com/recipe/huevos-rancheros-salad'],
 'fish': ['https://www.myrecipes.com/recipe/fish-tacos-6',
  'https://www.myrecipes.com/recipe/marinated-fish',
  'http://www.myrecipes.com/recipe/sweet-black-pepper-fish',
  'https://www.myrecipes.com/recipe/pepper-lime-dressing',
  'https://www.myrecipes.com/recipe/fish-stock-0',
  'https://www.myrecipes.com/recipe/fish-stew',
  'https://www.myrecipes.com/recipe/crispy-tofu-pad-thai-0',
  'http://www.myrecipes.com/recipe/fish-provencale',
  'http://www.myrecipes.com/recipe/broiled-fish',
  'https://www.myrecipes.com/recipe/fish-tacos',
  'https://www.myrecipes.com/recipe/fish-chowder-1',
  'https://www.myrecipes.com/recipe/fish-chips-0',
  'https://www.myrecipes.com/recipe/shrimp-and-vegetable-summer-rolls',
  'https://www.myrecipes.com/recipe/lemongrass-shrimp-over-rice-vermicelli-vegetables-bun-tom-nuong-xa'],
 'beef': ['https://www.myrecipes.com/recipe/corned-beef-cabbage-potatoes-carrots',
  'https://www.myrecipes.com/recipe/slow-cooker-beef-cabbage-potatoes-carrots'],
 'chicken': ['https://www.myrecipes.com/recipe/fried-chicken-wings',
  'http://www.myrecipes.com/recipe/carrot-onion-soup',
  'http://www.myrecipes.com/recipe/cheddar-cheese-soup',
  'http://www.myrecipes.com/recipe/black-bean-soup-13',
  'https://www.myrecipes.com/recipe/emilys-rice',
  'https://www.myrecipes.com/recipe/bell-pepper-chicken-with-feta-orzo',
  'https://www.myrecipes.com/recipe/chicken-nicoise-salad',
  'http://www.myrecipes.com/recipe/campbells-15-minute-chicken-rice-dinner',
  'https://www.myrecipes.com/recipe/white-bean-gratin',
  'https://www.myrecipes.com/recipe/sumac-chicken-cauliflower-carrots',
  'https://www.myrecipes.com/recipe/chicken-broccoli-rice-bowl',
  'https://www.myrecipes.com/recipe/basil-chicken-vegetables',
  'https://www.myrecipes.com/recipe/lemony-spanish-pepper-chicken-0',
  'https://www.myrecipes.com/recipe/hoisin-lime-marinated-grilled-chicken',
  'http://www.myrecipes.com/recipe/mao-pao-tofu',
  'https://www.myrecipes.com/recipe/golden-cauliflower-risotto',
  'https://www.myrecipes.com/recipe/fresh-lemon-pepper-chicken',
  'https://www.myrecipes.com/recipe/chipper-chicken-drumsticks',
  'https://www.myrecipes.com/recipe/parmesan-chicken',
  'https://www.myrecipes.com/recipe/lemon-pepper-chicken',
  'http://www.myrecipes.com/recipe/lemon-pepper-chicken-wings',
  'https://www.myrecipes.com/recipe/lemony-spanish-pepper-chicken',
  'http://www.myrecipes.com/recipe/peanut-noodles-with-tofu',
  'https://www.myrecipes.com/recipe/joses-black-beans-rice',
  'http://www.myrecipes.com/recipe/stuffed-alfredo-chicken',
  'https://www.myrecipes.com/recipe/curried-chicken-saute',
  'https://www.myrecipes.com/recipe/broccoli-rice-casseroles',
  'http://www.myrecipes.com/recipe/cauliflower-soup-with-shiitake',
  'https://www.myrecipes.com/recipe/butternut-squash-soup-5',
  'http://www.myrecipes.com/recipe/peppered-chicken-and-shrimp-jambalaya',
  'https://www.myrecipes.com/recipe/fiesta-chicken-with-rice-beans',
  'http://www.myrecipes.com/recipe/smothered-green-chile-pepper-chicken',
  'http://www.myrecipes.com/recipe/saffron-veal-stew',
  'http://www.myrecipes.com/recipe/fish-stew-0',
  'https://www.myrecipes.com/recipe/fried-rice-with-broccoli-eggs',
  'https://www.myrecipes.com/recipe/grilled-chicken-wings',
  'https://www.myrecipes.com/recipe/swanson-sensational-chicken-noodle-soup',
  'http://www.myrecipes.com/recipe/swanson-chicken-broccoli-dijon',
  'http://www.myrecipes.com/recipe/white-beans-rice',
  'http://www.myrecipes.com/recipe/sausage-red-cabbage',
  'https://www.myrecipes.com/recipe/cabbage-and-white-bean-soup-with-prosciutto',
  'http://www.myrecipes.com/recipe/wild-rice-and-kidney-bean-salad',
  'https://www.myrecipes.com/recipe/black-bean-chicken-chilaquiles',
  'https://www.myrecipes.com/recipe/cabbage-bean-potato-soup',
  'https://www.myrecipes.com/recipe/mediterranean-potato-chicken-salad',
  'http://www.myrecipes.com/recipe/provenale-pepper-chicken-salad',
  'https://www.myrecipes.com/recipe/cheesy-broccoli-rice-casserole',
  'http://www.myrecipes.com/recipe/salt-pepper-chicken-wings',
  'https://www.myrecipes.com/recipe/szechuan-style-tofu-with-peanuts',
  'http://www.myrecipes.com/recipe/mustard-spiced-cabbage-cannellini-beans-with-sausage'],
 'tofu': [],
 'pork': ['http://www.myrecipes.com/recipe/mao-pao-tofu',
  'http://www.myrecipes.com/recipe/stuffed-alfredo-chicken',
  'https://www.myrecipes.com/recipe/asian-style-meat-loaves',
  'https://www.myrecipes.com/recipe/sauted-pork-chops-nioise',
  'http://www.myrecipes.com/recipe/seared-pork-with-cranberry-orange-sauce'],
 'beans': ['https://www.myrecipes.com/recipe/joses-black-beans-rice',
  'http://www.myrecipes.com/recipe/bayou-red-beans-rice',
  'http://www.myrecipes.com/recipe/hearty-navy-bean-soup',
  'http://www.myrecipes.com/recipe/black-bean-soup-13',
  'http://www.myrecipes.com/recipe/broiled-fish',
  'https://www.myrecipes.com/recipe/white-bean-gratin',
  'https://www.myrecipes.com/recipe/black-bean-tostadas-with-cabbage-slaw',
  'https://www.myrecipes.com/recipe/garlicky-potatoes-green-beans'],
 'pepper': ['https://www.myrecipes.com/recipe/pepper-pepper-cheese-dip',
  'https://www.myrecipes.com/recipe/hot-citrus-honey-mustard-marinade',
  'https://www.myrecipes.com/recipe/caribbean-fish',
  'http://www.myrecipes.com/recipe/cheddar-cheese-soup',
  'https://www.myrecipes.com/recipe/bell-pepper-chicken-with-feta-orzo',
  'https://www.myrecipes.com/recipe/roasted-cauliflower',
  'https://www.myrecipes.com/recipe/roasted-bell-pepper-sauce',
  'https://www.myrecipes.com/recipe/basil-chicken-vegetables',
  'https://www.myrecipes.com/recipe/chipper-chicken-drumsticks',
  'https://www.myrecipes.com/recipe/roasted-cauliflower-turmeric-cumin',
  'https://www.myrecipes.com/recipe/blooming-bibb-lettuce-salad',
  'http://www.myrecipes.com/recipe/roasted-red-pepper-and-green-bean-salad',
  'https://www.myrecipes.com/recipe/parmesan-chicken',
  'https://www.myrecipes.com/recipe/cauliflower-galettes-chipotle-creme',
  'https://www.myrecipes.com/recipe/quick-vegetarian-chili-with-avocado-salsa',
  'https://www.myrecipes.com/recipe/fish-sticks',
  'http://www.myrecipes.com/recipe/tomato-avocado-salad',
  'https://www.myrecipes.com/recipe/savoy-cabbage-salad',
  'https://www.myrecipes.com/recipe/curried-chicken-saute',
  'http://www.myrecipes.com/recipe/cauliflower-soup-with-shiitake',
  'http://www.myrecipes.com/recipe/sweet-potato-rice-salad',
  'https://www.myrecipes.com/recipe/sweet-potato-salad-with-ham-curried-almonds',
  'http://www.myrecipes.com/recipe/broccoli-rabe-sesame-soy',
  'http://www.myrecipes.com/recipe/pepper-jelly-palmiers',
  'https://www.myrecipes.com/recipe/swanson-sensational-chicken-noodle-soup',
  'https://www.myrecipes.com/recipe/fish-tacos',
  'https://www.myrecipes.com/recipe/cauliflower-carrot-casserole',
  'http://www.myrecipes.com/recipe/wild-rice-and-kidney-bean-salad',
  'https://www.myrecipes.com/recipe/spiced-tofu-sandwiches',
  'https://www.myrecipes.com/recipe/fennel-apple-salad-with-lemon-shallot-dressing',
  'https://www.myrecipes.com/recipe/avocado-tomato-grilled-cheese',
  'https://www.myrecipes.com/recipe/cauliflower-green-onion-mash',
  'https://www.myrecipes.com/recipe/fish-chowder-1',
  'http://www.myrecipes.com/recipe/tofu-cheese-stuffed-manicotti',
  'http://www.myrecipes.com/recipe/campbells-15-minute-chicken-rice-dinner',
  'https://www.myrecipes.com/recipe/asparagus-red-pepper-manchego',
  'https://www.myrecipes.com/recipe/fried-chicken-wings',
  'https://www.myrecipes.com/recipe/cauliflower-garlic-thyme-vinaigrette',
  'https://www.myrecipes.com/recipe/plantation-beans-cabbage',
  'http://www.myrecipes.com/recipe/serrano-pepper-burgers',
  'http://www.myrecipes.com/recipe/black-bean-soup-13',
  'http://www.myrecipes.com/recipe/cream-cheese-tomato-onion-avocado-bagel',
  'http://www.myrecipes.com/recipe/cabbage-white-bean-casserole',
  'http://www.myrecipes.com/recipe/lemon-pepper-seasoning-salt',
  'http://www.myrecipes.com/recipe/seared-pork-with-cranberry-orange-sauce',
  'https://www.myrecipes.com/recipe/red-bell-pepper-coulis-1',
  'https://www.myrecipes.com/recipe/golden-cauliflower-risotto',
  'https://www.myrecipes.com/recipe/fish-tacos-6',
  'http://www.myrecipes.com/recipe/grilled-salmon-salade-nioise',
  'http://www.myrecipes.com/recipe/sweet-black-pepper-fish',
  'http://www.myrecipes.com/recipe/moroccan-chickpea-chili-0',
  'http://www.myrecipes.com/recipe/pickled-fish',
  'http://www.myrecipes.com/recipe/avocado-tomato-salad-0',
  'https://www.myrecipes.com/recipe/smothered-hamburger-steaks',
  'https://www.myrecipes.com/recipe/lemon-pepper-chicken',
  'http://www.myrecipes.com/recipe/fish-provencale',
  'http://www.myrecipes.com/recipe/asian-citrus-honey-mustard-marinade',
  'http://www.myrecipes.com/recipe/black-bean-corn-tostadas',
  'https://www.myrecipes.com/recipe/cabbage-green-bean-salad',
  'http://www.myrecipes.com/recipe/family-frittata',
  'https://www.myrecipes.com/recipe/red-cabbage-sausage-apple',
  'http://www.myrecipes.com/recipe/tomato-basil-soup',
  'http://www.myrecipes.com/recipe/peppered-chicken-and-shrimp-jambalaya',
  'https://www.myrecipes.com/recipe/egg-pepper-pitas',
  'https://www.myrecipes.com/recipe/pepper-relish-mini-meatloaves',
  'https://www.myrecipes.com/recipe/cauliflower-anchovy-breadcrumbs',
  'https://www.myrecipes.com/recipe/grilled-chicken-wings',
  'https://www.myrecipes.com/recipe/tex-mex-rice-salad',
  'http://www.myrecipes.com/recipe/herbed-citrus-honey-mustard-marinade',
  'http://www.myrecipes.com/recipe/cabbage-mushroom-toasts',
  'https://www.myrecipes.com/recipe/cauliflower-sesame-toasted-cashews',
  'http://www.myrecipes.com/recipe/sauteed-snow-peas-carrots-bell-peppers',
  'https://www.myrecipes.com/recipe/chilled-avocado-soup',
  'https://www.myrecipes.com/recipe/fish-tacos-5',
  'http://www.myrecipes.com/recipe/tofu-mushrooms-bell-peppers-sweet-and-sour-sauce',
  'http://www.myrecipes.com/recipe/garlic-red-pepper-broccoli',
  'https://www.myrecipes.com/recipe/fish-stock-0',
  'http://www.myrecipes.com/recipe/provenale-pepper-chicken-salad',
  'https://www.myrecipes.com/recipe/coffee-pepper-jelly-glaze',
  'http://www.myrecipes.com/recipe/mexican-eggs-with-beans',
  'https://www.myrecipes.com/recipe/boston-lettuce-radish-salad',
  'http://www.myrecipes.com/recipe/bayou-red-beans-rice',
  'https://www.myrecipes.com/recipe/spiced-roasted-cauliflower-carrots',
  'http://www.myrecipes.com/recipe/pepper-potato-ricotta-frittata',
  'https://www.myrecipes.com/recipe/jicama-slaw',
  'https://www.myrecipes.com/recipe/seasoned-white-beans-rice',
  'https://www.myrecipes.com/recipe/sumac-chicken-cauliflower-carrots',
  'https://www.myrecipes.com/recipe/sauted-pork-chops-nioise',
  'https://www.myrecipes.com/recipe/lemony-spanish-pepper-chicken-0',
  'https://www.myrecipes.com/recipe/cod-fresh-tomato-sauce',
  'https://www.myrecipes.com/recipe/rice-beans-with-avocado',
  'http://www.myrecipes.com/recipe/brown-butter-cauliflower-mash',
  'https://www.myrecipes.com/recipe/asian-style-slaw',
  'https://www.myrecipes.com/recipe/parmesan-herb-baked-flounder',
  'https://www.myrecipes.com/recipe/cabbage-bean-soup',
  'https://www.myrecipes.com/recipe/lemony-spanish-pepper-chicken',
  'http://www.myrecipes.com/recipe/chopped-salad-1',
  'https://www.myrecipes.com/recipe/broccoli-rice-casseroles',
  'http://www.myrecipes.com/recipe/beef-cheese-noodle-bake',
  'https://www.myrecipes.com/recipe/asian-style-meat-loaves',
  'http://www.myrecipes.com/recipe/do-it-all-marinade',
  'https://www.myrecipes.com/recipe/tomatoes-provenal',
  'http://www.myrecipes.com/recipe/swanson-chicken-broccoli-dijon',
  'https://www.myrecipes.com/recipe/red-pepper-couscous-0',
  'https://www.myrecipes.com/recipe/chili-con-carne-with-beans',
  'https://www.myrecipes.com/recipe/cabbage-white-beans',
  'https://www.myrecipes.com/recipe/romaine-peach-salad',
  'http://www.myrecipes.com/recipe/roasted-cauliflower-0',
  'https://www.myrecipes.com/recipe/smoked-tuna-dip',
  'https://www.myrecipes.com/recipe/citrus-honey-mustard-marinade',
  'https://www.myrecipes.com/recipe/lettuce-wedge-potato-salad',
  'https://www.myrecipes.com/recipe/red-lentil-burgers-with-aioli',
  'https://www.myrecipes.com/recipe/roasted-cauliflower-mashed-potatoes',
  'https://www.myrecipes.com/recipe/puerto-rican-cabbage-salad',
  'http://www.myrecipes.com/recipe/hearty-navy-bean-soup',
  'http://www.myrecipes.com/recipe/carrot-onion-soup',
  'https://www.myrecipes.com/recipe/red-cabbage-carrot-slaw',
  'https://www.myrecipes.com/recipe/huevos-rancheros-1',
  'https://www.myrecipes.com/recipe/pepper-lime-dressing',
  'https://www.myrecipes.com/recipe/new-potato-gratin-with-lima-beans-egg',
  'https://www.myrecipes.com/recipe/chicken-nicoise-salad',
  'http://www.myrecipes.com/recipe/chickpea-red-pepper-zucchini',
  'https://www.myrecipes.com/recipe/chicken-broccoli-rice-bowl',
  'https://www.myrecipes.com/recipe/oven-poached-salmon-garlic-broth',
  'http://www.myrecipes.com/recipe/zucchini-with-corn-cilantro-0',
  'https://www.myrecipes.com/recipe/asian-vegetable-stir-fry-1',
  'http://www.myrecipes.com/recipe/avocado-corn-salsa',
  'http://www.myrecipes.com/recipe/fish-tacos-4',
  'http://www.myrecipes.com/recipe/white-beans-rice',
  'http://www.myrecipes.com/recipe/broccoli-rice-cheese-bake',
  'https://www.myrecipes.com/recipe/triple-plum-salsa',
  'https://www.myrecipes.com/recipe/cabbage-bean-potato-soup',
  'http://www.myrecipes.com/recipe/grilled-flank-steak-with-curried-cauliflower-couscous',
  'https://www.myrecipes.com/recipe/cheesy-broccoli-rice-casserole',
  'https://www.myrecipes.com/recipe/rainbow-slaw',
  'http://www.myrecipes.com/recipe/chimichurri-broccoli',
  'http://www.myrecipes.com/recipe/creamy-garlic-herb-dip',
  'https://www.myrecipes.com/recipe/roasted-carrot-and-coconut-soup'],
 'cauliflower': ['https://www.myrecipes.com/recipe/spiced-roasted-cauliflower-carrots',
  'https://www.myrecipes.com/recipe/cauliflower-garlic-thyme-vinaigrette',
  'http://www.myrecipes.com/recipe/crunchy-radish-cauliflower-salad',
  'https://www.myrecipes.com/recipe/roasted-cauliflower',
  'https://www.myrecipes.com/recipe/sumac-chicken-cauliflower-carrots',
  'https://www.myrecipes.com/recipe/garlicky-potatoes-green-beans',
  'https://www.myrecipes.com/recipe/golden-cauliflower-risotto',
  'http://www.myrecipes.com/recipe/brown-butter-cauliflower-mash',
  'https://www.myrecipes.com/recipe/fall-vegetable-curry',
  'http://www.myrecipes.com/recipe/cauliflower-soup-with-shiitake',
  'https://www.myrecipes.com/recipe/cauliflower-anchovy-breadcrumbs',
  'https://www.myrecipes.com/recipe/cauliflower-coconut-curry-sauce',
  'https://www.myrecipes.com/recipe/grilled-eggplant-purple-cauliflower-caponata',
  'http://www.myrecipes.com/recipe/grilled-cauliflower',
  'https://www.myrecipes.com/recipe/cauliflower-sesame-toasted-cashews',
  'http://www.myrecipes.com/recipe/chubba-bubbas-broccoli-salad',
  'https://www.myrecipes.com/recipe/broccoli-cauliflower-carrot-salad',
  'http://www.myrecipes.com/recipe/roasted-cauliflower-0',
  'https://www.myrecipes.com/recipe/roasted-cauliflower-mashed-potatoes'],
 'rice': ['https://www.myrecipes.com/recipe/miso-carrot-dressing',
  'http://www.myrecipes.com/recipe/bayou-red-beans-rice',
  'http://www.myrecipes.com/recipe/broccoli-cheese-rice-casserole',
  'http://www.myrecipes.com/recipe/noodles-carrot-onion',
  'https://www.myrecipes.com/recipe/jicama-slaw',
  'https://www.myrecipes.com/recipe/pepper-lime-dressing',
  'https://www.myrecipes.com/recipe/emilys-rice',
  'https://www.myrecipes.com/recipe/chicken-broccoli-rice-bowl',
  'https://www.myrecipes.com/recipe/cod-fresh-tomato-sauce',
  'http://www.myrecipes.com/recipe/mao-pao-tofu',
  'https://www.myrecipes.com/recipe/rice-beans-with-avocado',
  'https://www.myrecipes.com/recipe/spicy-black-bean-burritos',
  'https://www.myrecipes.com/recipe/asian-style-slaw',
  'http://www.myrecipes.com/recipe/steamed-fish-on-soft-tofu-with-black-bean-sauce',
  'http://www.myrecipes.com/recipe/lemon-pepper-chicken-wings',
  'https://www.myrecipes.com/recipe/asian-vegetable-stir-fry-1',
  'https://www.myrecipes.com/recipe/quick-pickled-cabbage',
  'https://www.myrecipes.com/recipe/joses-black-beans-rice',
  'https://www.myrecipes.com/recipe/broccoli-rice-casseroles',
  'http://www.myrecipes.com/recipe/sweet-potato-rice-salad',
  'https://www.myrecipes.com/recipe/spicy-beans-with-coconut-milk',
  'http://www.myrecipes.com/recipe/peppered-chicken-and-shrimp-jambalaya',
  'https://www.myrecipes.com/recipe/broccoli-cheese-rice-casserole-0',
  'http://www.myrecipes.com/recipe/asian-marinated-salmon',
  'http://www.myrecipes.com/recipe/broccoli-rabe-sesame-soy',
  'https://www.myrecipes.com/recipe/asian-style-meat-loaves',
  'http://www.myrecipes.com/recipe/rice-bean-bowl',
  'https://www.myrecipes.com/recipe/crispy-tofu-pad-thai-0',
  'https://www.myrecipes.com/recipe/cauliflower-coconut-curry-sauce',
  'http://www.myrecipes.com/recipe/cheese-broccoli-rice-bake',
  'https://www.myrecipes.com/recipe/curried-noodles',
  'https://www.myrecipes.com/recipe/tex-mex-rice-salad',
  'https://www.myrecipes.com/recipe/shrimp-and-vegetable-summer-rolls',
  'https://www.myrecipes.com/recipe/lemongrass-shrimp-over-rice-vermicelli-vegetables-bun-tom-nuong-xa',
  'http://www.myrecipes.com/recipe/white-beans-rice',
  'http://www.myrecipes.com/recipe/wild-rice-and-kidney-bean-salad',
  'http://www.myrecipes.com/recipe/tofu-mushrooms-bell-peppers-sweet-and-sour-sauce',
  'https://www.myrecipes.com/recipe/broccoli-cauliflower-carrot-salad',
  'https://www.myrecipes.com/recipe/cheesy-broccoli-rice-casserole',
  'https://www.myrecipes.com/recipe/szechuan-style-tofu-with-peanuts',
  'http://www.myrecipes.com/recipe/campbells-15-minute-chicken-rice-dinner'],
 'cabbage': ['http://www.myrecipes.com/recipe/sausage-red-cabbage',
  'http://www.myrecipes.com/recipe/cabbage-sausage-casserole',
  'https://www.myrecipes.com/recipe/puerto-rican-cabbage-salad',
  'https://www.myrecipes.com/recipe/asian-style-slaw',
  'https://www.myrecipes.com/recipe/cabbage-and-white-bean-soup-with-prosciutto',
  'https://www.myrecipes.com/recipe/plantation-beans-cabbage',
  'https://www.myrecipes.com/recipe/cabbage-white-beans',
  'https://www.myrecipes.com/recipe/red-cabbage-sausage-apple',
  'https://www.myrecipes.com/recipe/savoy-cabbage-salad',
  'https://www.myrecipes.com/recipe/red-cabbage-carrot-slaw',
  'https://www.myrecipes.com/recipe/cabbage-bean-soup',
  'http://www.myrecipes.com/recipe/cabbage-white-bean-casserole',
  'https://www.myrecipes.com/recipe/rainbow-slaw',
  'https://www.myrecipes.com/recipe/black-bean-tostadas-with-cabbage-slaw',
  'https://www.myrecipes.com/recipe/asian-vegetable-stir-fry-1',
  'https://www.myrecipes.com/recipe/quick-pickled-cabbage',
  'http://www.myrecipes.com/recipe/mustard-spiced-cabbage-cannellini-beans-with-sausage',
  'http://www.myrecipes.com/recipe/cabbage-mushroom-toasts'],
 'lettuce': ['http://www.myrecipes.com/recipe/tomato-avocado-salad',
  'https://www.myrecipes.com/recipe/spicy-black-bean-burritos',
  'http://www.myrecipes.com/recipe/sweet-potato-rice-salad',
  'http://www.myrecipes.com/recipe/black-bean-corn-tostadas',
  'https://www.myrecipes.com/recipe/fish-tacos-6',
  'https://www.myrecipes.com/recipe/sweet-potato-salad-with-ham-curried-almonds',
  'https://www.myrecipes.com/recipe/romaine-peach-salad',
  'https://www.myrecipes.com/recipe/cobb-potato-salad',
  'http://www.myrecipes.com/recipe/fish-tacos-1',
  'https://www.myrecipes.com/recipe/mini-salami-puff-sandwiches',
  'https://www.myrecipes.com/recipe/fennel-apple-salad-with-lemon-shallot-dressing',
  'https://www.myrecipes.com/recipe/mediterranean-potato-chicken-salad',
  'http://www.myrecipes.com/recipe/pickled-fish',
  'https://www.myrecipes.com/recipe/red-lentil-burgers-with-aioli',
  'http://www.myrecipes.com/recipe/fish-tacos-4',
  'http://www.myrecipes.com/recipe/chopped-salad-1',
  'https://www.myrecipes.com/recipe/blast-sandwich'],
 'carrot': ['https://www.myrecipes.com/recipe/miso-carrot-dressing',
  'https://www.myrecipes.com/recipe/spiced-roasted-cauliflower-carrots',
  'https://www.myrecipes.com/recipe/puerto-rican-cabbage-salad',
  'http://www.myrecipes.com/recipe/chubba-bubbas-broccoli-salad',
  'http://www.myrecipes.com/recipe/hearty-navy-bean-soup',
  'https://www.myrecipes.com/recipe/butternut-squash-soup-5',
  'https://www.myrecipes.com/recipe/basil-chicken-vegetables',
  'http://www.myrecipes.com/recipe/noodles-carrot-onion',
  'http://www.myrecipes.com/recipe/beef-cheese-noodle-bake',
  'http://www.myrecipes.com/recipe/moroccan-chickpea-chili-0',
  'https://www.myrecipes.com/recipe/fried-rice-with-broccoli-eggs',
  'https://www.myrecipes.com/recipe/red-lentil-burgers-with-aioli',
  'https://www.myrecipes.com/recipe/lemongrass-shrimp-over-rice-vermicelli-vegetables-bun-tom-nuong-xa'],
 'onion': ['http://www.myrecipes.com/recipe/bayou-red-beans-rice',
  'https://www.myrecipes.com/recipe/puerto-rican-cabbage-salad',
  'https://www.myrecipes.com/recipe/fried-chicken-wings',
  'http://www.myrecipes.com/recipe/hearty-navy-bean-soup',
  'https://www.myrecipes.com/recipe/plantation-beans-cabbage',
  'http://www.myrecipes.com/recipe/broccoli-cheese-rice-casserole',
  'http://www.myrecipes.com/recipe/salsa-verde-eggs-benedict',
  'http://www.myrecipes.com/recipe/black-bean-soup-13',
  'http://www.myrecipes.com/recipe/cream-cheese-tomato-onion-avocado-bagel',
  'http://www.myrecipes.com/recipe/chickpea-red-pepper-zucchini',
  'https://www.myrecipes.com/recipe/fall-vegetable-curry',
  'https://www.myrecipes.com/recipe/spicy-black-bean-burritos',
  'http://www.myrecipes.com/recipe/moroccan-chickpea-chili-0',
  'http://www.myrecipes.com/recipe/avocado-tomato-salad-0',
  'https://www.myrecipes.com/recipe/fish-stew',
  'https://www.myrecipes.com/recipe/quick-vegetarian-chili-with-avocado-salsa',
  'http://www.myrecipes.com/recipe/black-bean-corn-tostadas',
  'https://www.myrecipes.com/recipe/broccoli-rice-casseroles',
  'https://www.myrecipes.com/recipe/butternut-squash-soup-5',
  'http://www.myrecipes.com/recipe/family-frittata',
  'https://www.myrecipes.com/recipe/red-cabbage-sausage-apple',
  'http://www.myrecipes.com/recipe/peppered-chicken-and-shrimp-jambalaya',
  'https://www.myrecipes.com/recipe/broccoli-cheese-rice-casserole-0',
  'https://www.myrecipes.com/recipe/pepper-relish-mini-meatloaves',
  'http://www.myrecipes.com/recipe/avocado-corn-salsa',
  'http://www.myrecipes.com/recipe/20-minute-black-bean-burgers',
  'http://www.myrecipes.com/recipe/beef-cheese-noodle-bake',
  'https://www.myrecipes.com/recipe/black-bean-tostadas-with-cabbage-slaw',
  'https://www.myrecipes.com/recipe/red-pepper-couscous-0',
  'http://www.myrecipes.com/recipe/chubba-bubbas-broccoli-salad',
  'https://www.myrecipes.com/recipe/chili-con-carne-with-beans',
  'http://www.myrecipes.com/recipe/tofu-mushrooms-bell-peppers-sweet-and-sour-sauce',
  'https://www.myrecipes.com/recipe/black-bean-chicken-chilaquiles',
  'https://www.myrecipes.com/recipe/romaine-peach-salad',
  'https://www.myrecipes.com/recipe/triple-plum-salsa',
  'https://www.myrecipes.com/recipe/lettuce-wedge-potato-salad',
  'https://www.myrecipes.com/recipe/cheesy-broccoli-rice-casserole',
  'https://www.myrecipes.com/recipe/fish-tacos-3',
  'https://www.myrecipes.com/recipe/fish-tacos-2',
  'https://www.myrecipes.com/recipe/red-lentil-burgers-with-aioli',
  'http://www.myrecipes.com/recipe/mustard-spiced-cabbage-cannellini-beans-with-sausage',
  'https://www.myrecipes.com/recipe/roasted-carrot-and-coconut-soup'],
 'spinash': [],
 'potato': ['https://www.myrecipes.com/recipe/fall-vegetable-curry',
  'https://www.myrecipes.com/recipe/chipper-chicken-drumsticks',
  'http://www.myrecipes.com/recipe/family-frittata',
  'http://www.myrecipes.com/recipe/pepper-potato-ricotta-frittata',
  'https://www.myrecipes.com/recipe/roasted-cauliflower-mashed-potatoes'],
 'tomato': ['http://www.myrecipes.com/recipe/serrano-pepper-burgers',
  'http://www.myrecipes.com/recipe/black-bean-soup-13',
  'http://www.myrecipes.com/recipe/cream-cheese-tomato-onion-avocado-bagel',
  'http://www.myrecipes.com/recipe/garlic-parmesan-potatoes-green-beans-tomatoes',
  'https://www.myrecipes.com/recipe/fish-tacos-6',
  'http://www.myrecipes.com/recipe/moroccan-chickpea-chili-0',
  'http://www.myrecipes.com/recipe/fish-provencale',
  'http://www.myrecipes.com/recipe/tofu-jerky',
  'https://www.myrecipes.com/recipe/asian-vegetable-stir-fry-1',
  'https://www.myrecipes.com/recipe/joses-black-beans-rice',
  'http://www.myrecipes.com/recipe/tomato-basil-soup',
  'http://www.myrecipes.com/recipe/family-frittata',
  'http://www.myrecipes.com/recipe/beef-cheese-noodle-bake',
  'https://www.myrecipes.com/recipe/shrimp-salad-with-banana-peppers-black-beans',
  'https://www.myrecipes.com/recipe/tex-mex-rice-salad',
  'https://www.myrecipes.com/recipe/blast-sandwich',
  'https://www.myrecipes.com/recipe/avocado-tomato-grilled-cheese',
  'http://www.myrecipes.com/recipe/provenale-pepper-chicken-salad',
  'https://www.myrecipes.com/recipe/red-lentil-burgers-with-aioli'],
 'broccoli': ['http://www.myrecipes.com/recipe/chubba-bubbas-broccoli-salad',
  'https://www.myrecipes.com/recipe/broccoli-rice-casseroles',
  'http://www.myrecipes.com/recipe/tofu-mushrooms-bell-peppers-sweet-and-sour-sauce',
  'https://www.myrecipes.com/recipe/broccoli-cauliflower-carrot-salad',
  'http://www.myrecipes.com/recipe/garlic-red-pepper-broccoli',
  'http://www.myrecipes.com/recipe/broccoli-rabe-sesame-soy',
  'https://www.myrecipes.com/recipe/cheesy-broccoli-rice-casserole',
  'https://www.myrecipes.com/recipe/fried-rice-with-broccoli-eggs',
  'http://www.myrecipes.com/recipe/chimichurri-broccoli',
  'http://www.myrecipes.com/recipe/cheese-broccoli-rice-bake',
  'https://www.myrecipes.com/recipe/chicken-broccoli-rice-bowl',
  'http://www.myrecipes.com/recipe/swanson-chicken-broccoli-dijon',
  'http://www.myrecipes.com/recipe/campbells-15-minute-chicken-rice-dinner',
  'https://www.myrecipes.com/recipe/sheet-pan-baked-tilapia-roasted-vegetables']}

# %%
import mysql.connector
mycursor = mydb.cursor()

# %%
mydb = mysql.connector.connect(
    host='recipes-ca.czmmtifous4d.us-west-1.rds.amazonaws.com',
    user='admin',
    password='MY9TFk8xvKt37dslRotD',
    database='recipes')
# mydb.is_connected()

# %%
#mycursor.execute('SELECT * from recipes')
# print(mycursor.rowcount)
# mycursor.commit()
# Out:
# -1

# %%
counter = 0
for keys in ingre_dish:
    # keys is in ingredient tabel
    counter += 1
    sql = 'INSERT INTO ingredients (id, name) VALUES(%s, %s)'
    val = (counter, keys)
    mycursor.execute(sql, val)
#     for link in ingre_dish[keys]:
#         # check whether the recipe has already exsit
#         sql = "SELECT * from recipes WHERE "
#         if 
#         sql = "INSERT INTO recipes (name, text) VALUES (%s, %s)"
#         val = (link, )
mycursor.commit()
# Out:
# ---------------------------------------------------------------------------
# ReferenceError                            Traceback (most recent call last)
# <ipython-input-17-197e9bb1c63a> in <module>
#       5     sql = 'INSERT INTO ingredients (id, name) VALUES(%s, %s)'
#       6     val = (counter, keys)
# ----> 7     mycursor.execute(sql, val)
#       8 #     for link in ingre_dish[keys]:
#       9 #         # check whether the recipe has already exsit
#
# /usr/local/lib/python3.7/site-packages/mysql/connector/cursor.py in execute(self, operation, params, multi)
#     516             return None
#     517
# --> 518         if not self._connection:
#     519             raise errors.ProgrammingError("Cursor is not connected")
#     520
#
# ReferenceError: weakly-referenced object no longer exists

# %%
mycursor = mydb.cursor()
sql = "INSERT INTO recipes (name, text) VALUES (%s, %s)"
val = ("John", "Highway 21")
mycursor.execute(sql, val)

mydb.commit()
