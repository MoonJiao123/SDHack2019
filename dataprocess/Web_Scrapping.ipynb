# %%
from requests import get
from requests.exceptions import RequestException
from contextlib import closing
from bs4 import BeautifulSoup
import random

# %%
def simple_get(url):
    """
    Attempts to get the content at `url` by making an HTTP GET request.
    If the content-type of response is some kind of HTML/XML, return the
    text content, otherwise return None.
    """
    try:
        with closing(get(url, stream=True)) as resp:
            if is_good_response(resp):
                return resp.content
            else:
                return None

    except RequestException as e:
        log_error('Error during requests to {0} : {1}'.format(url, str(e)))
        return None
def is_good_response(resp):
    """
    Returns True if the response seems to be HTML, False otherwise.
    """
    content_type = resp.headers['Content-Type'].lower()
    return (resp.status_code == 200 
            and content_type is not None 
            and content_type.find('html') > -1)


def log_error(e):
    """
    It is always a good idea to log errors. 
    This function just prints them, but you can
    make it do anything.
    """
    print(e)

# %%
# Do not re-execute this!!!
ingre_dish = {}
ingre_dish_img = {}

# %%
ingredients = ['egg','milk','avocado','fish','beef','chicken','tofu','pork','beans','pepper','cauliflower',
              'rice','cabbage','lettuce','carrot','onion','spinash','potato','tomato','broccoli']

# initialize the 'ingredient-dishes_link' dictionary with 
# key: string - ingredient name
# value: list - list of links to recipe
for food in ingredients:
    ingre_dish[food] = []
    ingre_dish_img[food] = []

# %%
'''
Given the number of ingredients you want to look up,
Auto generate an url search ingre_num number of ingredients
'''
def autoURLGenerator(ingre_num):
    random.shuffle(ingredients)
    this_ingre = ingredients[0:ingre_num]
    url = 'https://www.myrecipes.com/search?q='
    # append the ingredient we want to look up behind the url
    for item in this_ingre:
        url += item+'+'
    url = url[:-1] # we don't want the extra '+' at the end
    return url

'''
Given an url of list of recipes, get all the links to specific recipe
'''
def getDishesURL(url):
    # Write byte to a file
    raw_html = simple_get(url)
    file = open('raw_html.html', 'wb')
    file.write(raw_html)
    file.close()
    html = open('raw_html.html').read()
    soup = BeautifulSoup(html,'html.parser')
    all_result = soup.find_all('a', attrs={'class':'search-result-title-link'})
    links = []
    for result in all_result:
        links.append(result.get('href'))
        
    return links

def updateDishes(links):
    for link in links:
        img_src = ''
        print(link)
        html = simple_get(link)
        soup = BeautifulSoup(html,'html.parser')
        result = soup.find('div', attrs={'class':'ingredients'})
        img_result = soup.find('meta', attrs={'name':'pinterest:media'})
        #image = img_result.find('img')
        img_src = img_result.get('content')
        print(img_src)
            
        try:
            ingredient_list = result.find_all('li')
        except:
            return      

        # turn all 'li tags' into strins for further parsing
        li_string = []
        for li in ingredient_list:
            li_string.append(li.string)

        for item in li_string:
            for word in item.split():
                if word in ingredients:
                    ingre_dish[word].append(link)
                    ingre_dish_img[word].append(img_src)

# %%
# train 10 epochs
for i in range(30):
    url = autoURLGenerator(random.randint(1,5))
    links = getDishesURL(url)
    updateDishes(links)
# Out:
# https://www.myrecipes.com/recipe/miso-carrot-dressing
# https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb
# https://www.myrecipes.com/recipe/parmesan-herb-baked-flounder
# https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb
# http://www.myrecipes.com/recipe/indian-style-tofu-cauliflower-with-chutney
# https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ck/10/04/italian-tofu-cauliflower-ck-x.jpg
# https://www.myrecipes.com/recipe/tofu-pine-nut-lettuce-wraps
# https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb
# https://www.myrecipes.com/recipe/tofu-carrot-ginger-dressing-with-miso
# https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ck/tofu-dressing-ck-522136-x.jpg
# https://www.myrecipes.com/recipe/lettuce-wedge-potato-salad
# https://cdn-image.myrecipes.com/sites/default/files/lettuce-wedge-potato-salad-ck.jpg
# https://www.myrecipes.com/recipe/cobb-potato-salad
# https://cdn-image.myrecipes.com/sites/default/files/image/recipes/sl/11/09/cobb-potato-salad-sl-x.jpg
# https://www.myrecipes.com/recipe/romaine-peach-salad
# https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb
# https://www.myrecipes.com/recipe/peruvian-ceviche
# https://cdn-image.myrecipes.com/sites/default/files/image/recipes/su/06/06/ceviche-su-1194615-x.jpg
# https://www.myrecipes.com/recipe/ginger-basil-vinaigrette
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-237-a676af9f39fc> in <module>
#       3     url = autoURLGenerator(random.randint(1,5))
#       4     links = getDishesURL(url)
# ----> 5     updateDishes(links)
#
# <ipython-input-235-0ff12082648c> in updateDishes(links)
#      35         img_src = ''
#      36         print(link)
# ---> 37         html = simple_get(link)
#      38         soup = BeautifulSoup(html,'html.parser')
#      39         result = soup.find('div', attrs={'class':'ingredients'})
#
# <ipython-input-232-11c8d23c43c6> in simple_get(url)
#       6     """
#       7     try:
# ----> 8         with closing(get(url, stream=True)) as resp:
#       9             if is_good_response(resp):
#      10                 return resp.content
#
# /usr/local/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /usr/local/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# /usr/local/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /usr/local/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# /usr/local/Cellar/python/3.7.4_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in getresponse(self)
#    1334         try:
#    1335             try:
# -> 1336                 response.begin()
#    1337             except ConnectionError:
#    1338                 self.close()
#
# /usr/local/Cellar/python/3.7.4_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in begin(self)
#     304         # read until we get a non-100 response
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#     308                 break
#
# /usr/local/Cellar/python/3.7.4_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in _read_status(self)
#     265
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#     269             raise LineTooLong("status line")
#
# /usr/local/Cellar/python/3.7.4_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /usr/local/Cellar/python/3.7.4_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# /usr/local/Cellar/python/3.7.4_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
ingre_dish_img
# Out:
# {'egg': ['https://cdn-image.myrecipes.com/sites/default/files/egg-noddle-stir-fry-broccoli-ck.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ck/quiche-ck-491421-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ck/06/01/cajun-quiche-ck-1142014-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ck/06/01/cajun-quiche-ck-1142014-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ck/06/01/cajun-quiche-ck-1142014-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/sl/14/03/classic-homemade-mayonnaise-sl-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ck/12/08/chicken-potato-leek-pie-mr-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ck/13/10/sweet-potato-chickpea-cakes-avocado-salsa-ck-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ck/00/09/lentil-burgers-ck-223470-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/egg-avocado-in-a-hole-1.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/hl/spinach-egg-breakfast-wrap-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/Campbells/swanson-sensational-chicken-noodle-soup-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/Campbells/swanson-chicken-broccoli-dijon-l.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/egg-avocado-in-a-hole-1.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/hl/spinach-egg-breakfast-wrap-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ck/08/12/potato-latkes-ck-1860088-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/oh/cwsl/bacon-egg-tomato-gratin-oh-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ck/13/10/sweet-potato-chickpea-cakes-avocado-salsa-ck-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/hl/spinach-egg-breakfast-wrap-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/thomas/eggwhite_florentine_angle_lid-l.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ck/00/01/egg-burritos-ck-426392-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ck/00/01/egg-burritos-ck-426392-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/hl/bacon-jalapeno-egg-sandwich-xl.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ck/06/04/pancakes-ck-1173796-x.jpg'],
#  'milk': ['https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ck/quiche-ck-491421-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/creamy-chunky-mashed-potatoes-roasted-cauliflower-su.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ck/13/01/creamy-light-potato-soup-ck-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/quick-creamy-potatoes-ck.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/hl/broccoli-cheese-stuffed-potatoes-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ck/12/08/chicken-potato-leek-pie-mr-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ay/09/09/scalloped-potatoes-ay-1916226-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/sl/13/12/coconut-cream-sl-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/hl/chilled-avocado-soup-xl.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ck/fish-curry-ck-1065564-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ck/cauliflower-ck-1134035-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/Campbells/swanson-chicken-broccoli-dijon-l.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/knorr/K-Broc-Alfredo-l.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/CountryCrock/2013/recipes/CheddarBroccoliChickenCass_420x420.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/kraft/ChsyChicknNBroccoliMac_l.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/hl/broccoli-cheese-stuffed-potatoes-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ck/04/08/curried-tofu-ck-686184-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/fw/09/stir-fry-lemon-fw-1928015-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/rs/2007/sauteed-chicken-rs-1639563-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/sl/08/01/rice-bowl-sl-1694203-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/sl/08/01/rice-bowl-sl-1694203-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/fw/13/almond-milk-rice-pudding-fw-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/oh/clfffwn/thai-green-curry-chicken-oh-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ay/09/09/scalloped-potatoes-ay-1916226-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/oh/cwsl/bacon-egg-tomato-gratin-oh-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/sponsor/pam/PAM-PotatoSausageandEggCaserole-420x420.png',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/sl/03142008/egg-casserole-sl-520791-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/sl/09/01/tomato-aioli-sl-1865400-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb'],
#  'avocado': ['https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ck/13/07/avocado-sauce-ck-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/sl/12/11/roasted-carrot-avocado-salad-sl-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ck/09/09/chilie-salad-ck-1918468-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ck/13/10/sweet-potato-chickpea-cakes-avocado-salsa-ck-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/baja-fish-avocado-tostada-ck.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/su/97/03/cowboy-caviar-su-522962-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/baja-fish-avocado-tostada-ck.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/egg-avocado-in-a-hole-1.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files
x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ck/02/10/sweet-potato-ck-522110-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/sl/09/01/tomato-aioli-sl-1865400-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ck/06/04/pancakes-ck-1173796-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/sl/13/08/cajun-potato-chips-coating-sl-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/su/06/06/ceviche-su-1194615-x.jpg'],
#  'tomato': ['https://cdn-image.myrecipes.com/sites/default/files/image/recipes/sl/08/02/pork-chops-sl-1704085-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/kalamata_and_sun-dried_tomato_brisket.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/kalamata_and_sun-dried_tomato_brisket.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ck/13/10/sweet-potato-chickpea-cakes-avocado-salsa-ck-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ck/04/11/stuffed-green-pepper-soup-mr-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/sl/14/05/serrano-pepper-burgers-sl-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ck/00/09/lentil-burgers-ck-223470-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/chipotle-black-bean-burgers-fried-egg-avocado-cl.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/fried-egg-avocado-sandwiches-ck-1804p51.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/spring-risotto-ck.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ay/14/01/tomato-white-bean-soup-ay-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/sponsor/birdseye/BE-GarlicParmPotnGreenBeans-420x420.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/sl/13/12/tomato-bisque-sl-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ck/14/01/braised-beef-onion-sweet-potato-parsnip-ck-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ck/05/01/beef-brisket-ck-1011337-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ck/13/10/sweet-potato-chickpea-cakes-avocado-salsa-ck-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ck/00/05/stir-fry-ck-222179-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/hl/tofu-jerky-xl.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ay/14/01/parmesan-baked-eggs-peppers-ay-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ck/03142008/family-frittata-ck-222678-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ck/05/12/paprikash-ck-1134115-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/cl/08/09/crab-soup-cl-1831920-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/hl/bacon-jalapeno-egg-sandwich-xl.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/sponsor/birdseye/BE-GarlicParmPotnGreenBeans-420x420.jpg'],
#  'broccoli': ['https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ck/14/01/stewed-bulgur-broccoli-rabe-poached-eggs-ck-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ck/fried-rice-ck-698679-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/egg-noddle-stir-fry-broccoli-ck.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ck/quiche-ck-491421-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/hl/broccoli-cheese-stuffed-potatoes-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ck/14/09/cheddar-broccoli-sweet-potatoes-ck-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/6043301_ftgoo3177_1_0.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/oh/12/beef-and-broccoli-oh-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/beef-broccoli-stir-fry-ay.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ck/02/07/potato-salad-ck-263952-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/fw/12/beef-broccoli-rabe-provolone-panini-fw-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ck/fried-rice-ck-698679-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/oh/wwar08/broccoli-slaw-oh-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ck/12/12/broccoli-rabe-white-beans-parmesan-ck-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ck/13/09/garlic-red-pepper-broccoli-ck-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/bubbas-broccoli-salad-sl.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/bubbas-broccoli-salad-sl.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/Campbells/swanson-chicken-broccoli-dijon-l.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/knorr/K-Broc-Alfredo-l.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/CountryCrock/2013/recipes/CheddarBroccoliChickenCass_420x420.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/kraft/ChsyChicknNBroccoliMac_l.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/icbinb/icbinb-pnnechixbrcli-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/1501624852/sheet-pan-baked-tilapia-roasted-vegetables-1709p65.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ck/14/01/stewed-bulgur-broccoli-rabe-poached-eggs-ck-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/1502828994/image-4_0.jpeg',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ay/11/02/orcchiette-broccoli-tomato-ay-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/hl/broccoli-cheese-stuffed-potatoes-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ck/14/09/cheddar-broccoli-sweet-potatoes-ck-x.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/styles/4_3_horizontal_-_1200x900/public?itok=Y6-bwmRb',
#   'https://cdn-image.myrecipes.com/sites/default/files/broccoli-steaks-tofu-fries-ck.jpg',
#   'https://cdn-image.myrecipes.com/sites/default/files/image/recipes/ck/01/12/tofu-stirfry-ck-356664-x.jpg']}

# %%
print(len(ingre_dish['egg']))
len(ingre_dish_img['egg'])
# Out:
# 32
# 32

# %%
for keys in ingredients:
    if len(ingre_dish[keys]) != len(ingre_dish_img[keys]):
        print(keys)
